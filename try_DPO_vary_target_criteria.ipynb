# %%
import pandas as pd
# Load the CSV file
df = pd.read_csv('responses_gemini_cleaned_2024-12-13_22-19-59.csv')

# Display the head of the dataframe
df
# Out:
#                                  encoded_related_studies  \
# 0      <STUDY>\nExample Title: Phase I Trial of Intra...
# 1      <STUDY>\nExample Title: Preoperative CA 19.9 L...
# 2      <STUDY>\nExample Title: Use of ICG-fluorescent...
# 3      <STUDY>\nExample Title: An Open-Label, Multice...
# 4      <STUDY>\nExample Title: Characterization of Pr...
# ...                                                  ...
# 31545  <STUDY>\nExample Title: Double-Blind, Placebo-...
# 31546  <STUDY>\nExample Title: Combining 90Y-ibritumo...
# 31547  <STUDY>\nExample Title: An Exploratory Biomark...
# 31548  <STUDY>\nExample Title: BRAF and Nevi.Nevi Are...
# 31549  <STUDY>\nExample Title: Fatigue Intervention C...
#
#                                                    title  \
# 0      Ipilimumab and Gemcitabine for Advanced Pancre...
# 1      Cytopathologic Margin Evaluation in Patients U...
# 2      A Pilot Study to Assess the Utility of Indocya...
# 3      A Phase 1, Multicenter, Open-label, Dose-Explo...
# 4      Lipoprotein Lipase Expression in Chronic Lymph...
# ...                                                  ...
# 31545  A Placebo-Controlled Study on the Effect of Ep...
# 31546  A Phase 1 Dose Finding Study of Lutetium (177L...
# 31547  A Phase II Study Of PD0332991 (Palbociclib) in...
# 31548  Melanocytic-Nevi-Counts During Chemotherapy of...
# 31549  Self-Management of Cancer-Related Fatigue by A...
#
#                                              description  \
# 0      #Study Description \nBrief Summary \nThis phas...
# 1      #Study Description \nBrief Summary \nThis stud...
# 2      #Study Description \nBrief Summary \nThe purpo...
# 3      #Study Description \nBrief Summary \nTo evalua...
# 4      #Study Description \nBrief Summary \nThe inves...
# ...                                                  ...
# 31545  #Study Description \nBrief Summary \nThe purpo...
# 31546  #Study Description \nBrief Summary \nThis stud...
# 31547  #Study Description \nBrief Summary \nThe purpo...
# 31548  #Study Description \nBrief Summary \nChanges i...
# 31549  #Study Description \nBrief Summary \nThis stud...
#
#                                         desired_criteria  \
# 0      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 1      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 2      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 3      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 4      #Eligibility Criteria:\nInclusion Criteria:\n\...
# ...                                                  ...
# 31545  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31546  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31547  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31548  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31549  #Eligibility Criteria:\nInclusion Criteria:\n\...
#
#                                                 messages  \
# 0      <EXAMPLE_STUDIES><STUDY>\nExample Title: Phase...
# 1      <EXAMPLE_STUDIES><STUDY>\nExample Title: Preop...
# 2      <EXAMPLE_STUDIES><STUDY>\nExample Title: Use o...
# 3      <EXAMPLE_STUDIES><STUDY>\nExample Title: An Op...
# 4      <EXAMPLE_STUDIES><STUDY>\nExample Title: Chara...
# ...                                                  ...
# 31545  <EXAMPLE_STUDIES><STUDY>\nExample Title: Doubl...
# 31546  <EXAMPLE_STUDIES><STUDY>\nExample Title: Combi...
# 31547  <EXAMPLE_STUDIES><STUDY>\nExample Title: An Ex...
# 31548  <EXAMPLE_STUDIES><STUDY>\nExample Title: BRAF ...
# 31549  <EXAMPLE_STUDIES><STUDY>\nExample Title: Fatig...
#
#                                                 response  \
# 0      {'candidates': [{'avgLogprobs': -0.77479867043...
# 1      {'candidates': [{'avgLogprobs': -0.84127956725...
# 2      {'candidates': [{'avgLogprobs': -0.64226021840...
# 3      {'candidates': [{'avgLogprobs': -0.74655739089...
# 4      {'candidates': [{'avgLogprobs': -0.50618463869...
# ...                                                  ...
# 31545  {'candidates': [{'avgLogprobs': -0.74310038893...
# 31546  {'candidates': [{'avgLogprobs': -0.62609487778...
# 31547  {'candidates': [{'avgLogprobs': -0.76479573230...
# 31548  {'candidates': [{'avgLogprobs': -0.55029999096...
# 31549  {'candidates': [{'avgLogprobs': -0.64892300321...
#
#                                                      CoT  criteria_leak  \
# 0      <STEP-BY-STEP-JUSTIFICATION>\n\n**Step 1: Unde...          False
# 1      <STEP-BY-STEP-JUSTIFICATION>\n\nThe study, "Cy...          False
# 2      <STEP-BY-STEP-JUSTIFICATION>\n\n**Step 1: Unde...          False
# 3      <STEP-BY-STEP-JUSTIFICATION>\n\nThe study titl...          False
# 4      <STEP-BY-STEP-JUSTIFICATION>\n\n**Step 1:  Und...          False
# ...                                                  ...            ...
# 31545  <STEP-BY-STEP-JUSTIFICATION>\n\n**Step 1: Esta...          False
# 31546  <STEP-BY-STEP-JUSTIFICATION>\nThis Phase 1 dos...          False
# 31547  <STEP-BY-STEP-JUSTIFICATION>\n\nThis Phase II ...          False
# 31548  <STEP-BY-STEP-JUSTIFICATION>\n\n**Step 1: Unde...          False
# 31549  <STEP-BY-STEP-JUSTIFICATION>\n\nThis study, ti...          False
#
#                                         cleaned_criteria
# 0      **Step 1: Understanding the Study's Core Objec...
# 1      The study, "Cytopathologic Margin Evaluation i...
# 2      **Step 1: Understanding the Study's Focus**\n\...
# 3      The study title, "A Phase 1, Multicenter, Open...
# 4      **Step 1:  Understanding the Study's Focus**\n...
# ...                                                  ...
# 31545  **Step 1: Establishing the Study's Focus**\n\n...
# 31546  This Phase 1 dose-finding study investigates t...
# 31547  This Phase II study investigates the effects o...
# 31548  **Step 1: Understanding the Study's Focus**\n\...
# 31549  This study, titled "Self-Management of Cancer-...
#
# [31550 rows x 9 columns]

# %%
## Add a new column to the dataframe uuid to store the unique identifier
import uuid
df['uuid'] = [uuid.uuid4() for _ in range(len(df.index))]
df

augmented_df = df[["uuid","encoded_related_studies",	"title",	"description",	"desired_criteria",	"messages"	]]
augmented_df
# Out:
#                                        uuid  \
# 0      cbcf025a-0c78-4014-a96f-ea6c3d87db00
# 1      62bc9c39-cadc-4e5f-9ed5-f69a2dce3442
# 2      2f7dfc1e-41a6-417e-a87b-2617ec7892a0
# 3      d6773da3-e995-4ae0-aea4-de851f415db1
# 4      2c93bac8-c045-4b3e-956b-165c89d2b68d
# ...                                     ...
# 31545  1d2a6c6d-6367-4b86-b300-f10bb228b54c
# 31546  5a972da4-7dd9-4325-ab12-0b9ddfee1385
# 31547  949535be-f66a-40a3-8540-121d60817c28
# 31548  d37155ea-6b1b-4c12-a7af-5320bce55bcc
# 31549  e56ef7b3-93ac-4e57-a006-b2e6729566c4
#
#                                  encoded_related_studies  \
# 0      <STUDY>\nExample Title: Phase I Trial of Intra...
# 1      <STUDY>\nExample Title: Preoperative CA 19.9 L...
# 2      <STUDY>\nExample Title: Use of ICG-fluorescent...
# 3      <STUDY>\nExample Title: An Open-Label, Multice...
# 4      <STUDY>\nExample Title: Characterization of Pr...
# ...                                                  ...
# 31545  <STUDY>\nExample Title: Double-Blind, Placebo-...
# 31546  <STUDY>\nExample Title: Combining 90Y-ibritumo...
# 31547  <STUDY>\nExample Title: An Exploratory Biomark...
# 31548  <STUDY>\nExample Title: BRAF and Nevi.Nevi Are...
# 31549  <STUDY>\nExample Title: Fatigue Intervention C...
#
#                                                    title  \
# 0      Ipilimumab and Gemcitabine for Advanced Pancre...
# 1      Cytopathologic Margin Evaluation in Patients U...
# 2      A Pilot Study to Assess the Utility of Indocya...
# 3      A Phase 1, Multicenter, Open-label, Dose-Explo...
# 4      Lipoprotein Lipase Expression in Chronic Lymph...
# ...                                                  ...
# 31545  A Placebo-Controlled Study on the Effect of Ep...
# 31546  A Phase 1 Dose Finding Study of Lutetium (177L...
# 31547  A Phase II Study Of PD0332991 (Palbociclib) in...
# 31548  Melanocytic-Nevi-Counts During Chemotherapy of...
# 31549  Self-Management of Cancer-Related Fatigue by A...
#
#                                              description  \
# 0      #Study Description \nBrief Summary \nThis phas...
# 1      #Study Description \nBrief Summary \nThis stud...
# 2      #Study Description \nBrief Summary \nThe purpo...
# 3      #Study Description \nBrief Summary \nTo evalua...
# 4      #Study Description \nBrief Summary \nThe inves...
# ...                                                  ...
# 31545  #Study Description \nBrief Summary \nThe purpo...
# 31546  #Study Description \nBrief Summary \nThis stud...
# 31547  #Study Description \nBrief Summary \nThe purpo...
# 31548  #Study Description \nBrief Summary \nChanges i...
# 31549  #Study Description \nBrief Summary \nThis stud...
#
#                                         desired_criteria  \
# 0      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 1      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 2      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 3      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 4      #Eligibility Criteria:\nInclusion Criteria:\n\...
# ...                                                  ...
# 31545  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31546  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31547  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31548  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31549  #Eligibility Criteria:\nInclusion Criteria:\n\...
#
#                                                 messages
# 0      <EXAMPLE_STUDIES><STUDY>\nExample Title: Phase...
# 1      <EXAMPLE_STUDIES><STUDY>\nExample Title: Preop...
# 2      <EXAMPLE_STUDIES><STUDY>\nExample Title: Use o...
# 3      <EXAMPLE_STUDIES><STUDY>\nExample Title: An Op...
# 4      <EXAMPLE_STUDIES><STUDY>\nExample Title: Chara...
# ...                                                  ...
# 31545  <EXAMPLE_STUDIES><STUDY>\nExample Title: Doubl...
# 31546  <EXAMPLE_STUDIES><STUDY>\nExample Title: Combi...
# 31547  <EXAMPLE_STUDIES><STUDY>\nExample Title: An Ex...
# 31548  <EXAMPLE_STUDIES><STUDY>\nExample Title: BRAF ...
# 31549  <EXAMPLE_STUDIES><STUDY>\nExample Title: Fatig...
#
# [31550 rows x 6 columns]

# %%
def gen_shitty_criteria_prompt_wo_retrive_and_cot(title: str, description: str):
      return f"""
Target Study Title: {title}
Target Study Description: {description}

Task Instruction:
1. Based on the "Target Study Title" and "Target Study Description" of the target study, please create a Eligibility Criteria for the target study.
4. Please provide the Eligibility Criteria in the following format (the item within the square brackets [] are the options that you can choose from):
<FORMAT>
#Eligibility Criteria:
Inclusion Criteria:

* Inclusion Criteria 1
* Inclusion Criteria 2
* Inclusion Criteria 3
* ...

Exclusion Criteria:

* Exclusion Criteria 1
* Exclusion Criteria 2
* Exclusion Criteria 3
* ...

##Sex :
[MALE|FEMALE|ALL]
##Ages : 
- Minimum Age : ... Years
- Maximum Age : ... Years
- Age Group (Child: birth-17, Adult: 18-64, Older Adult: 65+) : [ADULT|CHILD|OLDER ADULT] comma separated

##Accepts Healthy Volunteers:
 [YES|NO]
</FORMAT>
<Example>
#Eligibility Criteria:
Inclusion Criteria:

* Ability to give informed consent.
* Patients with primary or recurrent papillary Non muscle invasive bladder cancer (NMIBC).
* Complete transurethral resection of bladder tumor(TURBT).
* Normal cardiac, hematological, and renal functions.
* Patients with intermediate and high risk NMIBC confirmed by histopathology.

Exclusion Criteria:

* Inability to give informed consent.
* Patients with history of previous radiotherapy or systemic chemotherapy.
* Patients suffering from immuno-deficiency or other malignancies.
* Patients with history of hypersensitivity reaction to epirubicin.
* Examination under anesthesia (EUA) reveals palpable bladder mass.
* Patients with primary, single, less than 1cm papillary bladder tumor (high likelihood of being low risk).
* Suspicion of perforation of the bladder during TURBT.
* Patients who develop hematuria in the recovery room necessitating continuous bladder wash or endoscopic haemostasis.
* Patients with proven low risk NMIBC on histopathology.
##Sex :
ALL
##Ages : 
- Minimum Age : 18 Years
- Age Group (Child: birth-17, Adult: 18-64, Older Adult: 65+) : ADULT, OLDER_ADULT

##Accepts Healthy Volunteers:
 No
</Example>
"""

# %%
# from tqdm import tqdm

from vllm import LLM, SamplingParams
from transformers import AutoTokenizer

model_id = "neuralmagic/Meta-Llama-3.1-8B-Instruct-quantized.w8a16"
number_gpus = 1

tokenizer = AutoTokenizer.from_pretrained(model_id)

llm = LLM(model=model_id, tensor_parallel_size=number_gpus, max_model_len=8192)

def pipe(messages):
    sampling_params = SamplingParams(temperature=0, top_p=0.9, max_tokens=4096)
    prompts = tokenizer.apply_chat_template(messages, add_generation_prompt=True, tokenize=False)
    outputs = llm.generate(prompts, sampling_params)
    return [i.outputs[0].text for i in outputs]

# %%
def get_messages(prompt):
  return [
      {"role": "system", "content": "You are a eligibility criteria chatbot who always responds eligibility criteria in the given format!"},
      {"role": "user", "content": prompt},
  ]
augmented_df["shitty_criteria_prompt_wo_retrive_and_cot"] = ""
## generate the prompts and batch the messages into pipes of 20 also save the outputs to the dataframe
batch_size = 20
for i in tqdm(range(0, len(augmented_df), batch_size)):
    batch = augmented_df.iloc[i:i+batch_size]
    messages = [get_messages(gen_shitty_criteria_prompt_wo_retrive_and_cot(title, description)) for title, description in zip(batch["title"], batch["description"])]
    outputs = pipe(messages)
    print(outputs[-1])
    print(len(augmented_df.loc[i:i+batch_size-1, "shitty_criteria_prompt_wo_retrive_and_cot"]))
    augmented_df.loc[i:i+batch_size-1, "shitty_criteria_prompt_wo_retrive_and_cot"] = outputs
augmented_df

# %%
import pickle
import pandas as pd

# load  augmented_df.pkl from disk 
augmented_df = pd.read_pickle("augmented_df.pkl")
augmented_df
# Out:
#                                        uuid  \
# 0      9803c5a3-11ea-4e73-bd09-76b2ff964f43
# 1      234bccea-aef9-4eee-b379-36ad1bc8dc20
# 2      3171b801-d8ff-4e52-b8e7-718617a36269
# 3      927636da-4a8b-4e78-b8ad-14a90585a7a5
# 4      b26ab53d-82ff-405d-be68-cdb510994bc8
# ...                                     ...
# 31545  e848cd52-7395-423d-af8f-3ca0dd3efd4f
# 31546  8003276d-5818-43f9-b984-8f04d64c7b63
# 31547  15d8d691-5e70-433e-bada-84c42683e714
# 31548  12fc0952-010b-4f59-8eb6-b8f7b00db976
# 31549  42f0d400-9281-476c-b5f8-18e5deee693e
#
#                                  encoded_related_studies  \
# 0      <STUDY>\nExample Title: Phase I Trial of Intra...
# 1      <STUDY>\nExample Title: Preoperative CA 19.9 L...
# 2      <STUDY>\nExample Title: Use of ICG-fluorescent...
# 3      <STUDY>\nExample Title: An Open-Label, Multice...
# 4      <STUDY>\nExample Title: Characterization of Pr...
# ...                                                  ...
# 31545  <STUDY>\nExample Title: Double-Blind, Placebo-...
# 31546  <STUDY>\nExample Title: Combining 90Y-ibritumo...
# 31547  <STUDY>\nExample Title: An Exploratory Biomark...
# 31548  <STUDY>\nExample Title: BRAF and Nevi.Nevi Are...
# 31549  <STUDY>\nExample Title: Fatigue Intervention C...
#
#                                                    title  \
# 0      Ipilimumab and Gemcitabine for Advanced Pancre...
# 1      Cytopathologic Margin Evaluation in Patients U...
# 2      A Pilot Study to Assess the Utility of Indocya...
# 3      A Phase 1, Multicenter, Open-label, Dose-Explo...
# 4      Lipoprotein Lipase Expression in Chronic Lymph...
# ...                                                  ...
# 31545  A Placebo-Controlled Study on the Effect of Ep...
# 31546  A Phase 1 Dose Finding Study of Lutetium (177L...
# 31547  A Phase II Study Of PD0332991 (Palbociclib) in...
# 31548  Melanocytic-Nevi-Counts During Chemotherapy of...
# 31549  Self-Management of Cancer-Related Fatigue by A...
#
#                                              description  \
# 0      #Study Description \nBrief Summary \nThis phas...
# 1      #Study Description \nBrief Summary \nThis stud...
# 2      #Study Description \nBrief Summary \nThe purpo...
# 3      #Study Description \nBrief Summary \nTo evalua...
# 4      #Study Description \nBrief Summary \nThe inves...
# ...                                                  ...
# 31545  #Study Description \nBrief Summary \nThe purpo...
# 31546  #Study Description \nBrief Summary \nThis stud...
# 31547  #Study Description \nBrief Summary \nThe purpo...
# 31548  #Study Description \nBrief Summary \nChanges i...
# 31549  #Study Description \nBrief Summary \nThis stud...
#
#                                         desired_criteria  \
# 0      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 1      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 2      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 3      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 4      #Eligibility Criteria:\nInclusion Criteria:\n\...
# ...                                                  ...
# 31545  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31546  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31547  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31548  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31549  #Eligibility Criteria:\nInclusion Criteria:\n\...
#
#                                                 messages  \
# 0      <EXAMPLE_STUDIES><STUDY>\nExample Title: Phase...
# 1      <EXAMPLE_STUDIES><STUDY>\nExample Title: Preop...
# 2      <EXAMPLE_STUDIES><STUDY>\nExample Title: Use o...
# 3      <EXAMPLE_STUDIES><STUDY>\nExample Title: An Op...
# 4      <EXAMPLE_STUDIES><STUDY>\nExample Title: Chara...
# ...                                                  ...
# 31545  <EXAMPLE_STUDIES><STUDY>\nExample Title: Doubl...
# 31546  <EXAMPLE_STUDIES><STUDY>\nExample Title: Combi...
# 31547  <EXAMPLE_STUDIES><STUDY>\nExample Title: An Ex...
# 31548  <EXAMPLE_STUDIES><STUDY>\nExample Title: BRAF ...
# 31549  <EXAMPLE_STUDIES><STUDY>\nExample Title: Fatig...
#
#                shitty_criteria_prompt_wo_retrive_and_cot
# 0      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 1      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 2      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 3      #Eligibility Criteria:\nInclusion Criteria:\n\...
# 4      #Eligibility Criteria:\nInclusion Criteria:\n\...
# ...                                                  ...
# 31545  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31546  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31547  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31548  #Eligibility Criteria:\nInclusion Criteria:\n\...
# 31549  #Eligibility Criteria:\nInclusion Criteria:\n\...
#
# [31550 rows x 7 columns]

# %%
from prompt_gen import PromptGen

augmented_df["shitty_criteria_CoT"] = ""
## generate the prompts and batch the messages into pipes of 20 also save the outputs to the dataframe
batch_size = 20
from tqdm import tqdm
    batch = augmented_df.iloc[i:i+batch_size]
    messages = [PromptGen.gen_messages(PromptGen.user_prompt_template(encoded_related_studies, title, description, shitty_criteria)) for encoded_related_studies, title, description, shitty_criteria in zip(batch["encoded_related_studies"],batch["title"], batch["description"], batch["shitty_criteria_prompt_wo_retrive_and_cot"])]
    outputs = pipe(messages)
    print(outputs[-1])
    print(len(augmented_df.loc[i:i+batch_size-1, "shitty_criteria_CoT"]))
    augmented_df.loc[i:i+batch_size-1, "shitty_criteria_CoT"] = outputs
augmented_df

augmented_df.to_pickle("augmented_df_with_CoT.pkl")
